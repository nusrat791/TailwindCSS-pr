# %% [markdown]
# <a href="https://colab.research.google.com/github/nusrat791/TailwindCSS-pr/blob/main/prlabweek3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# issus with colab

# %% [markdown]
# opencv verion2

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# image matrix(numpy)

# %% [markdown]
# print working dir

# %%
# !cd /content
# !pwd
/root
# Out:
# /content
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4254921482.py in <cell line: 0>()
#       1 get_ipython().system('cd /content')
#       2 get_ipython().system('pwd')
# ----> 3 root()
#
# NameError: name 'root' is not defined

# %% [markdown]
# solution

# %%
#sol
# %cd /content
# %pwd
# Out:
# /content
# '/content'

# %% [markdown]
# 1.load data
# 2.explore
# 3. visualize
# 4. identify
# 5.split into train
# 6. prepare
# 7.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# reading the data

# %%
housing=pd.read_csv('/content/drive/MyDrive/housing.csv')

# %% [markdown]
# knowing the dataset

# %%
housing.shape
# Out:
# (20640, 10)

# %% [markdown]
# 4th ste:analysis the data

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# describe

# %% [markdown]
# housing.describe()

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing[housing["median_income"]>15]["longitude"]
# Out:
# 1566    -121.96
# 4352    -118.37
# 4604    -118.33
# 4605    -118.33
# 4606    -118.33
# 4626    -118.32
# 4678    -118.34
# 5242    -118.40
# 5247    -118.44
# 5248    -118.43
# 5257    -118.49
# 5275    -118.50
# 5281    -118.49
# 5291    -118.42
# 6391    -118.06
# 6399    -118.04
# 6590    -118.18
# 6591    -118.19
# 6592    -118.20
# 6727    -118.12
# 6736    -118.10
# 8805    -118.34
# 8846    -118.40
# 8847    -118.40
# 8848    -118.39
# 8849    -118.40
# 8850    -118.41
# 8851    -118.42
# 8852    -118.42
# 8853    -118.41
# 8854    -118.41
# 8878    -118.50
# 10673   -117.85
# 10760   -117.87
# 11520   -118.06
# 15241   -117.23
# 15693   -122.44
# 16171   -122.50
# 16910   -122.36
# 17107   -122.20
# 17108   -122.22
# 17110   -122.21
# 17111   -122.18
# 17118   -122.14
# 17166   -122.22
# 17170   -122.27
# 17858   -121.87
# 18501   -121.59
# 18504   -121.96
# Name: longitude, dtype: float64

# %%
housing.hist(bins=50,figsize=(16,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
housing.plot(kind="scatter",x="longitude",y="latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
housing.plot(kind="scatter",x="longitude",y="latitude",alpha=0.1)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
housing.plot(kind="scatter",x="median_income",y="median_house_value",alpha=0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
housing.plot(kind="scatter",x="longitude",y="latitude",alpha=0.1,s=housing["population"]/100,label="population",figsize=(10,7),c="median_house_value",cmap=plt.get_cmap("jet"),colorbar=True)

# %%
housing.plot(kind="scatter",x="longitude",y="latitude",alpha=0.1,s=housing["population"]/100,label="population")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
housing.plot(kind="scatter",x="longitude",y="latitude",alpha=0.1,s=housing["population"]/100,label="population",c="median_house_value",cmap=plt.get_cmap("jet"))
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
numerical_features=housing.select_dtypes(include=['number'])
corr_matrix=numerical_features.corr()

# %%
housing.hist(bins=5,figsize=(16,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
housing["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
housing[housing["ocean_proximity"]=="ISLAND"]["median_house_value"]
# Out:
# 8314    450000.0
# 8315    414700.0
# 8316    300000.0
# 8317    450000.0
# 8318    287500.0
# Name: median_house_value, dtype: float64

# %%
housing[housing["ocean_proximity"]=="NEAR BAY"].hist(bins=50,figsize=(16,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
hosting_na=housing.dropna(subset=["total_bedrooms"])
hosting_na.shape
# Out:
# (20433, 10)

# %%
dummies=pd.get_dummies(hosting_na.ocean_proximity)
dummies
housing_na_dummies=pd.concat([hosting_na,dummies],axis='columns')
housing_na_dummies.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# 30%=test
# 70%=train

# %%
train,test=train_test_split(housing,test_size=0.3,random_state=24)

# %%
print("train",len(train))
print("test",len(test))
# Out:
# train 14448
# test 6192

# %%
housing["median_house_value","median_house_value_cat"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('median_house_value', 'median_house_value_cat')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2069787130.py in <cell line: 0>()
# ...

# %%
housing["median_house_value"].hist()
# Out:
# <Axes: >

# %%
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np

# %%
housing["median_house_value_cat"]=pd.cut(housing["median_house_value"],
                                         bins=[0., 150000., 250000., 350000., 450000., np.inf],
                                         labels=[1, 2, 3, 4, 5])

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)

# %%
for train_index,test_index in split.split(housing,housing["median_house_value_cat"]):
  strat_train_set=housing.loc[train_index]
  strat_test_set=housing.loc[test_index]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'median_house_value_cat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3517340624.py in <cell line: 0>()
# ...

# %%
start_train.drop("median_house_value_cat",axis=1,inplace=True)
strat_test.drop("median_house_value_cat",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2816189935.py in <cell line: 0>()
# ----> 1 start_train.drop("median_house_value_cat",axis=1,inplace=True)
#       2 strat_test.drop("median_house_value_cat",axis=1,inplace=True)
#
# NameError: name 'start_train' is not defined

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(start_train,figsize=(64,64))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2760628621.py in <cell line: 0>()
#       1 from pandas.plotting import scatter_matrix
# ----> 2 scatter_matrix(start_train,figsize=(64,64))
#
# NameError: name 'start_train' is not defined

# %%
median=start_train_attr["total_bedrooms"].median()
start_train_attr["total_bedrooms"].fillna(median,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1567137599.py in <cell line: 0>()
# ----> 1 median=start_train_attr["total_bedrooms"].median()
#       2 start_train_attr["total_bedrooms"].fillna(median,inplace=True)
#
# NameError: name 'start_train_attr' is not defined

# %%
start_train_cat=start_train_attr[["ocean_proximity"]].copy

# %%
from skleran.preprocessing import ordinalencoder
oe= ordinalencoder()
start_train_cat=oe.fit_transform(start_train_cat)

# %%
start_train_cat.toarray()

# %%
start_train_num=srart_train_attr.drop("ocean_proximity",axis=1,inplace=false)

# %%
from sklearn.preprocessing import OneHotEncoder
ss=standscaler()
strat_train_num=ss.fit_transform(strat_train_num)

# %%
type(start_train_num[0][0])

# %%
srart_train_num.shape

# %%
pd.dataframe(start_train_num).describe()
