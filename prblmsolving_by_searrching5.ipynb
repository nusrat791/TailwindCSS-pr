# %% [markdown]
# <a href="https://colab.research.google.com/github/nusrat791/TailwindCSS-pr/blob/main/prblmsolving_by_searrching5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# bfs

# %%
graph={
  '5':['3','7'],
  '3':['2','4'],
  '7':['8'],
  '2':[],
  '4':['8'],
  '8':[],

}

# %%
graph={
    '5':['3','7']
    '3':['2','4']
    '7':['8'],
    '2':[],
    '4':['8'],
    '8':[],
}

# %%
queue=[]
visited=[]
def bfs(visited,graph,node):
  visited.append(node)

# %%
queue=[]
visited=[]
def bfs(visited,graph,node):
  visited.append(node)
  queue.append(node)
  while queue:
    s=queue.pop(0)
    print(s,end=" ")
    for neighbour in graph[s]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

# %%
bfs(graph,visited,'5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-604347797.py in <cell line: 0>()
# ----> 1 bfs(graph,visited,'5')
#
# /tmp/ipython-input-3041981226.py in bfs(visited, graph, node)
#       2 visited=[]
#       3 def bfs(visited,graph,node):
# ----> 4   visited.append(node)
#       5   queue.append(node)
#       6   while queue:
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
print("type rock,paper,scissor")
choices=[rock,paper,scissor]
while True:
  user_choice=input("enter choice").lower()
  if user_choice not in choices:
    print("invalid choice")
    continue

  computer_choice=random.choice(choices)
  print("computer choice",computer_choice)
  if user_choice==computer_choice:
    print("tie")
    elif user_choice=="rock":
    if computer_choice=="scissor":
      print("you win")
    else:
      print("you lose")

# %%
from collections import deque
N=3

class PuzzleState:
  def __init__(self,board,x,y,depth):
    self.board=board
    self.x=x
    self.y=y
    self.depth=depth
row=[0,0,-1,1]
col=[-1,1,0,0]

def is_goal_state(board):
  goal=[
      [1,2,3],
      [4,5,6],
      [7,8,0]
  ]

  return board==goal

def is_valid(x,y):
  return0 0<=x<N and 0<=y<N

def print_boaed(board):
  for row in board:
    print(''.join(map(str,row)))
    print('------------')

def solve_puzzle_bfs(start,x,y):
  q=deque()
  visited = set()
  q.append(PuzzleState(start,x,y,0))
  visited.add(tupple(map(tuple,start)))

  while q:
    curr=q.popleft()

    print('depth:{curr.depth}')
    print_board(curr.board)

    if is_goal_state(curr.board):
      print(f'goal state at depth {curr.depth}')
      return

    for i in range(4):
      new_x,new_y=curr.x+row[i],curr.y+col[i]

      return
      if is_valid(new_x,new_y)
       new_board=[row[:] for row in curr.board]
       new_board[curr.x][curr.y],new_board[new_x][new_y]=new_board[new_x][new_y],new_board[curr.x][curr.y]

       if tupple(map(tuple,new_board)) not in visited:
         q.append(PuzzleState(new_board,new_x,new_y,curr.depth+1))

  print('no solutionfound(bfs brute force reached depth limit)')

if _name_=='_main_':
  start=[
      [1,2,3],
      [4,0,5],
      [6,7,8]


  ]
  x,y=1,1

  print('initial state:')
  print_board(start)

  solve_puzzle_bfs(start,x,y)
# Out:
#   File "/tmp/ipython-input-2815130239.py", line 23
#     return0 0<=x<N and 0<=y<N
#             ^
# SyntaxError: invalid syntax

# %%
import random
def --init--(self,board,x,y,):
    self.board=board
    self.x=x
    self.y=y

row=[0,1,2]
col=[0,1,2]

def is_goal_state(board):
  goal=[
      [0,0,0],
      [0,0,0],
      [0,0,#]
  ]


   print("board")


    def represent(board)
    for i in range(3):
        for j in range(3):
          print(board[i][j],end=" ")
        print()
    print()

    def check_win(board)
     for i in range(3):
        if board[i][0]==board[i][1]==board[i][2]!=0:
          return board[i][0]
    def game()
     x=input()
     y=input()
     board[x][y]=1


    def human_moves={up,down,left,right}
      list=[up,down,right,left]


      computer_moves=random.board(list)
# Out:
#   File "/tmp/ipython-input-3892500303.py", line 2
#     board=[
#           ^
# SyntaxError: '[' was never closed
